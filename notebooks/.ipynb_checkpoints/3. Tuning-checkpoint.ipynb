# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split, KFold
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, mean_squared_log_error
from lightgbm import LGBMRegressor
import lightgbm as lgbm
from lightgbm import early_stopping

import yaml
import json
import optuna
from typing import Callable
from tqdm import tqdm
import joblib
import warnings

warnings.filterwarnings("ignore")

# %% [markdown]
# # Описание и импорт данных

# %% [markdown]
# Задачей данного проекта является предсказание кассовых сборов фильмов.
# Данные были собраны с сайта Кинопоиск с использованием собственного парсера. Были выбраны данные о фильмах США за все годы с первых 1000 страниц сайта (на следующих страницах информации о кассовых сборах практически не было).

# %% [markdown]
# Проект был разделен на несколько частей, каждая из которых представляет собой отдельный Jupyter ноутбук:
# 1. EDA – исследовательский анализ данных, который включает в себя первичный анализ данных, обработку пропусков, преобразование признаков выявление закономерностей и взаимосвязей в данных, формулировка гипотез и визуализация наиболее важных признаков (данный EDA является упрощенной версией исследовательского проекта - ссылка)
# 2. Baseline – обучение baseline модели и оценка ее метрик
# 3. **Tuning – подбор гиперпараметров модели для улучшения качества предсказаний и оценка полученных метрик**

# %% [markdown]
# **Описания полей:**
# - rating - пользовательский рейтинг на Кинопоиске
# - production_year - год производства
# - director - режиссер
# - age_rating - возрастной рейтинг
# - duration - продолжительность в минутах
# - budget - бюджет фильма
# - **target - кассовые сборы фильма**
# - target_log - прологарифмированное значение target (распределение более близкое к нормальному)
# - main_genre - основной жанр фильма
# - month - месяц выпуска фильма
# - director_film_count - количество фильмов, которые снял режиссер
# - actors_fame - слава актеров, которые снимались в фильме (слава = количество фильмов, в которых снимались актеры)

# %%
config_path = '../config/config.yaml'
config = yaml.load(open(config_path, encoding='utf-8'), Loader=yaml.FullLoader)

config_train = config['train']
RAND = config_train['random_state']
N_FOLDS = config_train['n_folds']

# %%
df_train = pd.read_csv(config_train['train_data_path'])
df_val = pd.read_csv(config_train['val_data_path'])
df_test = pd.read_csv(config_train['test_data_path'])

# %%
df_train.head()
# Out:
#      rating  production_year      director age_rating  duration        budget  \
# 0  6.300000             2015    Джон Уоттс        18+        88  8.000000e+05
# 1  7.066667             2004         Other  undefined        95  3.113265e+06
# 2  7.700000             1998  Энди Теннант         0+       121  2.600000e+07
# 3  6.700000             2002  Тодд Филлипс        16+        88  2.400000e+07
# 4  6.696041             1999         Other  undefined       100  1.533853e+07
#
#    target_log      main_genre     month  director_film_count  actors_fame
# 0   11.875191         триллер    январь                    5           40
# 1   10.605173  документальный  сентябрь                    1           24
# 2   18.400536           драма      июль                   10           46
# 3   18.280746         комедия   февраль                   11           81
# 4   10.203555           драма    апрель                    1           41

# %% [markdown]
# # Подготовка данных

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7785 entries, 0 to 7784
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   rating               7785 non-null   float64
#  1   production_year      7785 non-null   int64
#  2   director             7785 non-null   object
#  3   age_rating           7785 non-null   object
#  4   duration             7785 non-null   int64
#  5   budget               7785 non-null   float64
#  6   target_log           7785 non-null   float64
#  7   main_genre           7785 non-null   object
#  8   month                7785 non-null   object
#  9   director_film_count  7785 non-null   int64
#  10  actors_fame          7785 non-null   int64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 669.2+ KB

# %%
df_train.describe()
# Out:
#             rating  production_year     duration        budget   target_log  \
# count  7785.000000      7785.000000  7785.000000  7.785000e+03  7785.000000
# mean      6.482979      2000.653051   102.017213  2.584692e+07    14.742531
# std       0.849815        18.315396    17.948037  3.349345e+07     3.244874
# min       1.400000      1913.000000     0.000000  2.200000e+02     3.401197
# 25%       6.000000      1992.000000    91.000000  6.000000e+06    12.302282
# 50%       6.600000      2005.000000    99.000000  1.533853e+07    15.273428
# 75%       7.066667      2014.000000   110.000000  2.780000e+07    17.295954
# max       8.900000      2024.000000   319.000000  3.785000e+08    21.796118
#
#        director_film_count  actors_fame
# count          7785.000000  7785.000000
# mean              5.031985    30.165832
# std               5.849112    25.954593
# min               1.000000     1.000000
# 25%               1.000000     8.000000
# 50%               3.000000    23.000000
# 75%               7.000000    46.000000
# max              42.000000   175.000000

# %%
df_train.describe(include='object')
# Out:
#        director age_rating main_genre     month
# count      7785       7785       7785      7785
# unique      501          6         25        12
# top       Other        18+      драма  сентябрь
# freq       4963       2667       2433      1084

# %% [markdown]
# - как видим, пропущенных значений в данных нет (они были обработаны на предыдущем этапе) и у всех переменных правильные типы данных
# - так как в данном проекте используется CatBoost, то все признаки типа object нужно перевести в тип category, что избавит нас от бинаризации категориальных признаков

# %% [markdown]
# - преобразуем все столбцы типа object в тип category

# %%
def transform_to_category(df: pd.DataFrame, cat_cols: list) -> pd.DataFrame:
    '''
    Преобразует столбцы из типа object в тип category
    Parameters
    ------------
    df: pd.DataFrame
        дата фрейм, в котором нужно преобразовать тип стобцов
    cat_cols: list
        список категориальных столбцов
    
    Returns
    -----------
    дата фрейм с преобразованными столбцами
    '''
    df[cat_cols] = df[cat_cols].astype('category')
    return df

# %%
df_train = transform_to_category(df_train, config_train['category_cols'])
df_val = transform_to_category(df_val, config_train['category_cols'])
df_test = transform_to_category(df_test, config_train['category_cols'])

# %% [markdown]
# - разделим данные на X и y

# %%
def split_to_x_y(df: pd.DataFrame, target_col: str) -> tuple:
    '''
    Делит дата фрейм на X и y
    
    Parameters
    -----------
    df: pd.DataFrame
        дата фрейм с данными
    target_col: str
        название таргет переменной
        
    Returns
    ----------
    разделенный дата фрейм на X и y
    '''
    X = df.drop([target_col], axis=1)
    y = df[target_col]
    return X, y

# %%
X_train, y_train = split_to_x_y(df_train, config_train['target_column'])
X_val, y_val = split_to_x_y(df_val, config_train['target_column'])
X_test, y_test = split_to_x_y(df_test, config_train['target_column'])

# %% [markdown]
# # Подбор параметров

# %% [markdown]
# По результатам предыдущего ноутбука было решено использовать **LightGBM**  и для нее подбирать параметры. В качестве метрики для оценки была выбрана **MAE**, так как она более устойчива к выбросам.
#
# Основные параметры модели:
# - n_estimators - максимальное количество деревьев
# - learning_rate - скорость обучения
# - num_leaves - максимальное количество листьев в дереве
# - max_depth - максимальная глубина деревьев
# - max_bin - максимальное количество бинов, на которые будут разбиты target значения
# - min_data_in_leaf - минимальное количество данных в листе
# - bagging_fraction - процент выборок, которые будут использоваться для обучения каждого дерева
# - bagging_freq - каждые k итераций нужно выполнять bagging
# - lambda_l1 - l1 регуляризация
# - lambda_l2 - l2 регуляризация
# - min_split_gain - минимальное снижение потерь, необходимое для дальнейшего разбиения на листы

# %% [markdown]
# - попробуем подобрать параметры для модели, чтобы улушить ее результаты

# %%
# целевая функция
def objective_lgb(trial, X_train: np.ndarray, y_train: np.ndarray,
                  X_val: np.ndarray, y_val: np.ndarray, random_state: int,
                  cat_features: list):
    '''
    Функция для подбора параметров с помощью optuna
    
    Parameters
    ------------
    trial
        текущая попытка подбора
    X_train: np.ndarray
        тренировочные значения X
    y_train: np.ndarray
        тренировочные значения y
    X_val: np.ndarray
        валидационные значения X
    y_val: np.ndarray
        валидационные значения y
    random_state: int
    cat_features: list
        список с категориальными переменными в наборе
    
    Returns
    -----------
    MAE на текущем trial
    '''
    lgb_params = {
        "n_estimators":
        trial.suggest_categorical("n_estimators", [857]),
        #         trial.suggest_int("n_estimators", 300, 1000),
        "learning_rate":
        trial.suggest_categorical("learning_rate", [0.045309611206922125]),
        #                 trial.suggest_float("learning_rate", 0.001, 0.3, log=True),
        "num_leaves":
        trial.suggest_int("num_leaves", 20, 100),
        "max_depth":
        trial.suggest_int("max_depth", 3, 9),
        "max_bin":
        trial.suggest_int("max_bin", 50, 500),
        "min_data_in_leaf":
        trial.suggest_int("min_data_in_leaf", 30, 150),
        "bagging_fraction":
        trial.suggest_float("bagging_fraction", 0.5, 1),
        "bagging_freq":
        trial.suggest_int("bagging_freq", 1, 5),
        "lambda_l1":
        trial.suggest_int("lambda_l1", 0, 20),
        "lambda_l2":
        trial.suggest_int("lambda_l2", 0, 20),
        "min_split_gain":
        trial.suggest_int("min_split_gain", 0, 20),
        "colsample_bytree":
        trial.suggest_float("colsample_bytree", 0.2, 1.0),
        'objective':
        trial.suggest_categorical("objective", ['mae']),
        'verbosity':
        trial.suggest_categorical("verbosity", [-1]),
        "random_state":
        trial.suggest_categorical("random_state", [random_state])
    }

    model = LGBMRegressor(**lgb_params)
    model.fit(X_train,
              y_train,
              eval_set=[(X_val, y_val)],
              eval_metric="mae",
              categorical_feature=cat_features,
              callbacks=[early_stopping(stopping_rounds=100)])

    y_pred = model.predict(X_val)

    return mean_absolute_error(np.exp(y_val), np.exp(y_pred))

# %%
# создание study и подбор параметров
study_lgbm = optuna.create_study(direction="minimize", study_name="lgbm")
func = lambda trial: objective_lgb(trial,
                                   X_train,
                                   y_train,
                                   X_val,
                                   y_val,
                                   random_state=RAND,
                                   cat_features=config_train['category_cols'])
study_lgbm.optimize(func, n_trials=config_train['n_trials'], show_progress_bar=True)
# Out:
# [I 2024-12-02 14:51:21,512] A new study created in memory with name: lgbm
#   0%|          | 0/100 [00:00<?, ?it/s]
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [430]	valid_0's l1: 1.60841
# [I 2024-12-02 14:51:21,765] Trial 0 finished with value: 29570326.59577785 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 75, 'max_depth': 4, 'max_bin': 415, 'min_data_in_leaf': 120, 'bagging_fraction': 0.9522027457455953, 'bagging_freq': 1, 'lambda_l1': 14, 'lambda_l2': 20, 'min_split_gain': 15, 'colsample_bytree': 0.6644924612169694, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 0 with value: 29570326.59577785.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [142]	valid_0's l1: 1.47192
# [I 2024-12-02 14:51:21,890] Trial 1 finished with value: 28478097.194770325 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 37, 'max_depth': 8, 'max_bin': 403, 'min_data_in_leaf': 89, 'bagging_fraction': 0.9306008268904038, 'bagging_freq': 5, 'lambda_l1': 13, 'lambda_l2': 2, 'min_split_gain': 4, 'colsample_bytree': 0.8506518357728854, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 1 with value: 28478097.194770325.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [244]	valid_0's l1: 1.58033
# [I 2024-12-02 14:51:21,988] Trial 2 finished with value: 29582904.15536502 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 52, 'max_depth': 5, 'max_bin': 244, 'min_data_in_leaf': 45, 'bagging_fraction': 0.9968700096852279, 'bagging_freq': 1, 'lambda_l1': 12, 'lambda_l2': 2, 'min_split_gain': 17, 'colsample_bytree': 0.5340500950817494, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 1 with value: 28478097.194770325.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [157]	valid_0's l1: 1.51804
# [I 2024-12-02 14:51:22,070] Trial 3 finished with value: 29295051.099063884 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 39, 'max_depth': 7, 'max_bin': 291, 'min_data_in_leaf': 63, 'bagging_fraction': 0.5572555140347106, 'bagging_freq': 4, 'lambda_l1': 16, 'lambda_l2': 0, 'min_split_gain': 4, 'colsample_bytree': 0.5532984054457222, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 1 with value: 28478097.194770325.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [233]	valid_0's l1: 1.45585
# [I 2024-12-02 14:51:22,253] Trial 4 finished with value: 28288641.76732421 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 70, 'max_depth': 9, 'max_bin': 150, 'min_data_in_leaf': 132, 'bagging_fraction': 0.7798371867377143, 'bagging_freq': 2, 'lambda_l1': 11, 'lambda_l2': 17, 'min_split_gain': 2, 'colsample_bytree': 0.9468206041900786, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 4 with value: 28288641.76732421.
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [841]	valid_0's l1: 1.40662
# [I 2024-12-02 14:51:22,920] Trial 5 finished with value: 28565650.73924026 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 98, 'max_depth': 6, 'max_bin': 379, 'min_data_in_leaf': 62, 'bagging_fraction': 0.6495423660447845, 'bagging_freq': 1, 'lambda_l1': 11, 'lambda_l2': 0, 'min_split_gain': 0, 'colsample_bytree': 0.7676160555398652, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 4 with value: 28288641.76732421.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [311]	valid_0's l1: 1.55173
# [I 2024-12-02 14:51:23,067] Trial 6 finished with value: 30288129.26707437 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 57, 'max_depth': 4, 'max_bin': 435, 'min_data_in_leaf': 100, 'bagging_fraction': 0.9429744348432669, 'bagging_freq': 3, 'lambda_l1': 2, 'lambda_l2': 1, 'min_split_gain': 7, 'colsample_bytree': 0.41181487271317607, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 4 with value: 28288641.76732421.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [127]	valid_0's l1: 1.49611
# [I 2024-12-02 14:51:23,180] Trial 7 finished with value: 28498235.883551475 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 99, 'max_depth': 8, 'max_bin': 226, 'min_data_in_leaf': 120, 'bagging_fraction': 0.9658693162148784, 'bagging_freq': 2, 'lambda_l1': 3, 'lambda_l2': 6, 'min_split_gain': 7, 'colsample_bytree': 0.8039443368872377, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 4 with value: 28288641.76732421.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [266]	valid_0's l1: 1.69981
# [I 2024-12-02 14:51:23,267] Trial 8 finished with value: 31598786.082608037 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 31, 'max_depth': 4, 'max_bin': 260, 'min_data_in_leaf': 73, 'bagging_fraction': 0.7254152350917267, 'bagging_freq': 5, 'lambda_l1': 4, 'lambda_l2': 0, 'min_split_gain': 20, 'colsample_bytree': 0.21226802513284754, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 4 with value: 28288641.76732421.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [91]	valid_0's l1: 1.66951
# [I 2024-12-02 14:51:23,324] Trial 9 finished with value: 30521512.491715245 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 91, 'max_depth': 6, 'max_bin': 475, 'min_data_in_leaf': 52, 'bagging_fraction': 0.5401840055010624, 'bagging_freq': 4, 'lambda_l1': 17, 'lambda_l2': 10, 'min_split_gain': 20, 'colsample_bytree': 0.5980192194431735, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 4 with value: 28288641.76732421.
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [798]	valid_0's l1: 1.42089
# [I 2024-12-02 14:51:24,149] Trial 10 finished with value: 28897953.318244148 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 74, 'max_depth': 9, 'max_bin': 59, 'min_data_in_leaf': 148, 'bagging_fraction': 0.8235399889728604, 'bagging_freq': 2, 'lambda_l1': 20, 'lambda_l2': 19, 'min_split_gain': 0, 'colsample_bytree': 0.9897685929616444, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 4 with value: 28288641.76732421.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [123]	valid_0's l1: 1.47725
# [I 2024-12-02 14:51:24,320] Trial 11 finished with value: 28168422.107189607 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 45, 'max_depth': 9, 'max_bin': 105, 'min_data_in_leaf': 94, 'bagging_fraction': 0.8390289126960787, 'bagging_freq': 5, 'lambda_l1': 7, 'lambda_l2': 15, 'min_split_gain': 5, 'colsample_bytree': 0.972208892648011, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 11 with value: 28168422.107189607.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [100]	valid_0's l1: 1.56156
# [I 2024-12-02 14:51:24,458] Trial 12 finished with value: 29373034.579870656 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 71, 'max_depth': 9, 'max_bin': 83, 'min_data_in_leaf': 149, 'bagging_fraction': 0.8323556186540465, 'bagging_freq': 3, 'lambda_l1': 7, 'lambda_l2': 16, 'min_split_gain': 11, 'colsample_bytree': 0.9882278563878762, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 11 with value: 28168422.107189607.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [141]	valid_0's l1: 1.48447
# [I 2024-12-02 14:51:24,636] Trial 13 finished with value: 28591656.33850797 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 22, 'max_depth': 8, 'max_bin': 147, 'min_data_in_leaf': 121, 'bagging_fraction': 0.818611208456341, 'bagging_freq': 2, 'lambda_l1': 8, 'lambda_l2': 14, 'min_split_gain': 4, 'colsample_bytree': 0.9110991589993677, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 11 with value: 28168422.107189607.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [128]	valid_0's l1: 1.54267
# [I 2024-12-02 14:51:24,796] Trial 14 finished with value: 28960570.072157856 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 48, 'max_depth': 9, 'max_bin': 166, 'min_data_in_leaf': 99, 'bagging_fraction': 0.7183796487177778, 'bagging_freq': 4, 'lambda_l1': 7, 'lambda_l2': 14, 'min_split_gain': 9, 'colsample_bytree': 0.7206077604503672, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 11 with value: 28168422.107189607.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [194]	valid_0's l1: 1.44546
# [I 2024-12-02 14:51:25,027] Trial 15 finished with value: 28262560.252859175 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 64, 'max_depth': 7, 'max_bin': 131, 'min_data_in_leaf': 136, 'bagging_fraction': 0.8630573479289141, 'bagging_freq': 3, 'lambda_l1': 9, 'lambda_l2': 11, 'min_split_gain': 2, 'colsample_bytree': 0.9115250147487521, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 11 with value: 28168422.107189607.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [128]	valid_0's l1: 1.47638
# [I 2024-12-02 14:51:25,208] Trial 16 finished with value: 28392164.23250373 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 63, 'max_depth': 7, 'max_bin': 111, 'min_data_in_leaf': 84, 'bagging_fraction': 0.8764316149240391, 'bagging_freq': 4, 'lambda_l1': 0, 'lambda_l2': 10, 'min_split_gain': 7, 'colsample_bytree': 0.8604865608304931, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 11 with value: 28168422.107189607.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [130]	valid_0's l1: 1.526
# [I 2024-12-02 14:51:25,358] Trial 17 finished with value: 29044594.284409475 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 85, 'max_depth': 7, 'max_bin': 191, 'min_data_in_leaf': 31, 'bagging_fraction': 0.8956493802797334, 'bagging_freq': 5, 'lambda_l1': 9, 'lambda_l2': 7, 'min_split_gain': 13, 'colsample_bytree': 0.4500326394946299, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 11 with value: 28168422.107189607.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [519]	valid_0's l1: 1.48073
# [I 2024-12-02 14:51:25,642] Trial 18 finished with value: 30591254.268158957 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 47, 'max_depth': 3, 'max_bin': 321, 'min_data_in_leaf': 107, 'bagging_fraction': 0.6409894694012002, 'bagging_freq': 3, 'lambda_l1': 5, 'lambda_l2': 11, 'min_split_gain': 2, 'colsample_bytree': 0.6962922799816178, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 11 with value: 28168422.107189607.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [106]	valid_0's l1: 1.54937
# [I 2024-12-02 14:51:25,788] Trial 19 finished with value: 29256783.20407257 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 62, 'max_depth': 8, 'max_bin': 108, 'min_data_in_leaf': 128, 'bagging_fraction': 0.7663116430971014, 'bagging_freq': 3, 'lambda_l1': 6, 'lambda_l2': 13, 'min_split_gain': 10, 'colsample_bytree': 0.8910004218879635, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 11 with value: 28168422.107189607.
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [838]	valid_0's l1: 1.57558
# [I 2024-12-02 14:51:26,093] Trial 20 finished with value: 32630054.62107059 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 20, 'max_depth': 5, 'max_bin': 199, 'min_data_in_leaf': 138, 'bagging_fraction': 0.8751988249772302, 'bagging_freq': 4, 'lambda_l1': 9, 'lambda_l2': 5, 'min_split_gain': 5, 'colsample_bytree': 0.20214671159860187, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 11 with value: 28168422.107189607.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [226]	valid_0's l1: 1.45975
# [I 2024-12-02 14:51:26,335] Trial 21 finished with value: 28317037.856666267 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 69, 'max_depth': 9, 'max_bin': 140, 'min_data_in_leaf': 136, 'bagging_fraction': 0.7696033697251484, 'bagging_freq': 2, 'lambda_l1': 10, 'lambda_l2': 17, 'min_split_gain': 2, 'colsample_bytree': 0.9436212911361146, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 11 with value: 28168422.107189607.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [392]	valid_0's l1: 1.44038
# [I 2024-12-02 14:51:26,657] Trial 22 finished with value: 28242080.72488896 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 81, 'max_depth': 8, 'max_bin': 57, 'min_data_in_leaf': 106, 'bagging_fraction': 0.8046569100757095, 'bagging_freq': 2, 'lambda_l1': 15, 'lambda_l2': 17, 'min_split_gain': 1, 'colsample_bytree': 0.8086508172183136, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 11 with value: 28168422.107189607.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [545]	valid_0's l1: 1.41156
# [I 2024-12-02 14:51:27,372] Trial 23 finished with value: 28597496.557390057 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 83, 'max_depth': 7, 'max_bin': 51, 'min_data_in_leaf': 108, 'bagging_fraction': 0.8503965383422467, 'bagging_freq': 3, 'lambda_l1': 15, 'lambda_l2': 12, 'min_split_gain': 0, 'colsample_bytree': 0.85851041384161, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 11 with value: 28168422.107189607.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [165]	valid_0's l1: 1.48495
# [I 2024-12-02 14:51:27,574] Trial 24 finished with value: 28403205.51849396 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 83, 'max_depth': 8, 'max_bin': 105, 'min_data_in_leaf': 80, 'bagging_fraction': 0.6996666180349483, 'bagging_freq': 2, 'lambda_l1': 18, 'lambda_l2': 8, 'min_split_gain': 2, 'colsample_bytree': 0.7791837251065166, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 11 with value: 28168422.107189607.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [139]	valid_0's l1: 1.5157
# [I 2024-12-02 14:51:27,748] Trial 25 finished with value: 28641106.186964594 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 56, 'max_depth': 6, 'max_bin': 87, 'min_data_in_leaf': 111, 'bagging_fraction': 0.9048708981725202, 'bagging_freq': 3, 'lambda_l1': 13, 'lambda_l2': 18, 'min_split_gain': 5, 'colsample_bytree': 0.8042448122296779, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 11 with value: 28168422.107189607.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [152]	valid_0's l1: 1.49321
# [I 2024-12-02 14:51:27,948] Trial 26 finished with value: 28279238.864045896 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 40, 'max_depth': 8, 'max_bin': 197, 'min_data_in_leaf': 94, 'bagging_fraction': 0.7947770507306351, 'bagging_freq': 5, 'lambda_l1': 19, 'lambda_l2': 15, 'min_split_gain': 3, 'colsample_bytree': 0.991908790237569, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 11 with value: 28168422.107189607.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [128]	valid_0's l1: 1.48423
# [I 2024-12-02 14:51:28,129] Trial 27 finished with value: 28057594.23520705 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 80, 'max_depth': 7, 'max_bin': 55, 'min_data_in_leaf': 75, 'bagging_fraction': 0.8539352557347945, 'bagging_freq': 3, 'lambda_l1': 6, 'lambda_l2': 12, 'min_split_gain': 6, 'colsample_bytree': 0.919644881391137, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 27 with value: 28057594.23520705.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [119]	valid_0's l1: 1.53304
# [I 2024-12-02 14:51:28,288] Trial 28 finished with value: 28841824.718937766 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 90, 'max_depth': 8, 'max_bin': 50, 'min_data_in_leaf': 72, 'bagging_fraction': 0.6785293560383014, 'bagging_freq': 4, 'lambda_l1': 5, 'lambda_l2': 15, 'min_split_gain': 8, 'colsample_bytree': 0.7376181613497437, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 27 with value: 28057594.23520705.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [501]	valid_0's l1: 1.48764
# [I 2024-12-02 14:51:28,549] Trial 29 finished with value: 28261714.21733009 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 78, 'max_depth': 6, 'max_bin': 81, 'min_data_in_leaf': 79, 'bagging_fraction': 0.8061135738586949, 'bagging_freq': 1, 'lambda_l1': 2, 'lambda_l2': 20, 'min_split_gain': 6, 'colsample_bytree': 0.6631561867530628, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 27 with value: 28057594.23520705.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [457]	valid_0's l1: 1.54872
# [I 2024-12-02 14:51:28,768] Trial 30 finished with value: 28816929.597574975 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 78, 'max_depth': 9, 'max_bin': 80, 'min_data_in_leaf': 92, 'bagging_fraction': 0.9088823432833881, 'bagging_freq': 1, 'lambda_l1': 14, 'lambda_l2': 18, 'min_split_gain': 12, 'colsample_bytree': 0.8221299846696479, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 27 with value: 28057594.23520705.
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [852]	valid_0's l1: 1.46999
# [I 2024-12-02 14:51:29,055] Trial 31 finished with value: 27846061.84842275 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 78, 'max_depth': 6, 'max_bin': 87, 'min_data_in_leaf': 77, 'bagging_fraction': 0.8025380742034733, 'bagging_freq': 1, 'lambda_l1': 0, 'lambda_l2': 19, 'min_split_gain': 6, 'colsample_bytree': 0.6413194064790778, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 31 with value: 27846061.84842275.
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [853]	valid_0's l1: 1.47278
# [I 2024-12-02 14:51:29,364] Trial 32 finished with value: 28530099.394530818 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 89, 'max_depth': 5, 'max_bin': 120, 'min_data_in_leaf': 69, 'bagging_fraction': 0.7455467744481865, 'bagging_freq': 1, 'lambda_l1': 0, 'lambda_l2': 20, 'min_split_gain': 5, 'colsample_bytree': 0.6300390503268201, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 31 with value: 27846061.84842275.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [127]	valid_0's l1: 1.49986
# [I 2024-12-02 14:51:29,539] Trial 33 finished with value: 28573020.129651275 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 78, 'max_depth': 7, 'max_bin': 74, 'min_data_in_leaf': 86, 'bagging_fraction': 0.8491176140307954, 'bagging_freq': 2, 'lambda_l1': 2, 'lambda_l2': 16, 'min_split_gain': 9, 'colsample_bytree': 0.9356032134881237, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 31 with value: 27846061.84842275.
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [856]	valid_0's l1: 1.48638
# [I 2024-12-02 14:51:29,820] Trial 34 finished with value: 28224565.219547115 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 95, 'max_depth': 6, 'max_bin': 172, 'min_data_in_leaf': 50, 'bagging_fraction': 0.7930295153662987, 'bagging_freq': 1, 'lambda_l1': 7, 'lambda_l2': 18, 'min_split_gain': 6, 'colsample_bytree': 0.4691816460188384, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 31 with value: 27846061.84842275.
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [845]	valid_0's l1: 1.556
# [I 2024-12-02 14:51:30,098] Trial 35 finished with value: 29864142.146587443 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 95, 'max_depth': 5, 'max_bin': 168, 'min_data_in_leaf': 49, 'bagging_fraction': 0.7531427051940018, 'bagging_freq': 1, 'lambda_l1': 6, 'lambda_l2': 19, 'min_split_gain': 8, 'colsample_bytree': 0.403191297279935, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 31 with value: 27846061.84842275.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [371]	valid_0's l1: 1.47508
# [I 2024-12-02 14:51:30,343] Trial 36 finished with value: 28128847.68492144 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 94, 'max_depth': 6, 'max_bin': 172, 'min_data_in_leaf': 35, 'bagging_fraction': 0.9642478343840366, 'bagging_freq': 1, 'lambda_l1': 4, 'lambda_l2': 13, 'min_split_gain': 6, 'colsample_bytree': 0.4860336372300331, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 31 with value: 27846061.84842275.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [173]	valid_0's l1: 1.53063
# [I 2024-12-02 14:51:30,523] Trial 37 finished with value: 29502151.475081205 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 33, 'max_depth': 6, 'max_bin': 319, 'min_data_in_leaf': 32, 'bagging_fraction': 0.9770347140919292, 'bagging_freq': 5, 'lambda_l1': 1, 'lambda_l2': 13, 'min_split_gain': 15, 'colsample_bytree': 0.3289126468483595, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 31 with value: 27846061.84842275.
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [842]	valid_0's l1: 1.46155
# [I 2024-12-02 14:51:30,873] Trial 38 finished with value: 28153776.85351402 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 87, 'max_depth': 5, 'max_bin': 220, 'min_data_in_leaf': 60, 'bagging_fraction': 0.9337708042390208, 'bagging_freq': 1, 'lambda_l1': 4, 'lambda_l2': 9, 'min_split_gain': 4, 'colsample_bytree': 0.5246085111197271, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 31 with value: 27846061.84842275.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [547]	valid_0's l1: 1.45983
# [I 2024-12-02 14:51:31,155] Trial 39 finished with value: 28044943.753197063 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 87, 'max_depth': 5, 'max_bin': 235, 'min_data_in_leaf': 40, 'bagging_fraction': 0.9254450007358648, 'bagging_freq': 1, 'lambda_l1': 4, 'lambda_l2': 4, 'min_split_gain': 4, 'colsample_bytree': 0.5388481820648182, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 31 with value: 27846061.84842275.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [347]	valid_0's l1: 1.52586
# [I 2024-12-02 14:51:31,399] Trial 40 finished with value: 28497808.701734003 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 100, 'max_depth': 4, 'max_bin': 277, 'min_data_in_leaf': 40, 'bagging_fraction': 0.9892309380606122, 'bagging_freq': 1, 'lambda_l1': 3, 'lambda_l2': 4, 'min_split_gain': 6, 'colsample_bytree': 0.5749422912154607, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 31 with value: 27846061.84842275.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [616]	valid_0's l1: 1.4686
# [I 2024-12-02 14:51:31,747] Trial 41 finished with value: 28172341.468159165 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 89, 'max_depth': 5, 'max_bin': 239, 'min_data_in_leaf': 60, 'bagging_fraction': 0.9504828528575481, 'bagging_freq': 1, 'lambda_l1': 4, 'lambda_l2': 8, 'min_split_gain': 4, 'colsample_bytree': 0.5299537234972904, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 31 with value: 27846061.84842275.
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [856]	valid_0's l1: 1.43653
# [I 2024-12-02 14:51:32,188] Trial 42 finished with value: 27783505.808718402 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 93, 'max_depth': 5, 'max_bin': 217, 'min_data_in_leaf': 42, 'bagging_fraction': 0.9293242945109189, 'bagging_freq': 1, 'lambda_l1': 4, 'lambda_l2': 3, 'min_split_gain': 3, 'colsample_bytree': 0.5124004894920371, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial
and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 44, 'max_depth': 8, 'max_bin': 435, 'min_data_in_leaf': 34, 'bagging_fraction': 0.672121487835082, 'bagging_freq': 3, 'lambda_l1': 1, 'lambda_l2': 1, 'min_split_gain': 0, 'colsample_bytree': 0.7575740525157425, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 64 with value: 27013629.171407126.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [433]	valid_0's l1: 1.38009
# [I 2024-12-02 14:51:50,989] Trial 71 finished with value: 27522646.80284283 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 37, 'max_depth': 7, 'max_bin': 454, 'min_data_in_leaf': 31, 'bagging_fraction': 0.7831103538747388, 'bagging_freq': 2, 'lambda_l1': 2, 'lambda_l2': 0, 'min_split_gain': 0, 'colsample_bytree': 0.6910951514136808, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 64 with value: 27013629.171407126.
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [805]	valid_0's l1: 1.37739
# [I 2024-12-02 14:51:51,817] Trial 72 finished with value: 27402371.91162698 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 43, 'max_depth': 7, 'max_bin': 463, 'min_data_in_leaf': 37, 'bagging_fraction': 0.8106511129901561, 'bagging_freq': 2, 'lambda_l1': 1, 'lambda_l2': 0, 'min_split_gain': 1, 'colsample_bytree': 0.7260707370222588, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 64 with value: 27013629.171407126.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [267]	valid_0's l1: 1.40848
# [I 2024-12-02 14:51:52,115] Trial 73 finished with value: 26957452.814154092 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 48, 'max_depth': 7, 'max_bin': 438, 'min_data_in_leaf': 30, 'bagging_fraction': 0.7565443706895258, 'bagging_freq': 2, 'lambda_l1': 3, 'lambda_l2': 2, 'min_split_gain': 2, 'colsample_bytree': 0.67518921137393, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 73 with value: 26957452.814154092.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [225]	valid_0's l1: 1.43766
# [I 2024-12-02 14:51:52,351] Trial 74 finished with value: 27875100.48052943 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 48, 'max_depth': 7, 'max_bin': 424, 'min_data_in_leaf': 33, 'bagging_fraction': 0.7473727914879089, 'bagging_freq': 2, 'lambda_l1': 11, 'lambda_l2': 2, 'min_split_gain': 2, 'colsample_bytree': 0.7742959772858337, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 73 with value: 26957452.814154092.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [479]	valid_0's l1: 1.40317
# [I 2024-12-02 14:51:52,887] Trial 75 finished with value: 28493731.51039517 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 27, 'max_depth': 7, 'max_bin': 483, 'min_data_in_leaf': 39, 'bagging_fraction': 0.6215458581107501, 'bagging_freq': 2, 'lambda_l1': 3, 'lambda_l2': 2, 'min_split_gain': 1, 'colsample_bytree': 0.66577079176937, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 73 with value: 26957452.814154092.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [571]	valid_0's l1: 1.36493
# [I 2024-12-02 14:51:53,817] Trial 76 finished with value: 27148497.10797192 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 56, 'max_depth': 8, 'max_bin': 440, 'min_data_in_leaf': 30, 'bagging_fraction': 0.8414538806436511, 'bagging_freq': 2, 'lambda_l1': 4, 'lambda_l2': 1, 'min_split_gain': 0, 'colsample_bytree': 0.6119102217223921, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 73 with value: 26957452.814154092.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [292]	valid_0's l1: 1.40733
# [I 2024-12-02 14:51:54,270] Trial 77 finished with value: 27604796.95759306 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 56, 'max_depth': 8, 'max_bin': 442, 'min_data_in_leaf': 48, 'bagging_fraction': 0.8412686582715614, 'bagging_freq': 3, 'lambda_l1': 6, 'lambda_l2': 1, 'min_split_gain': 2, 'colsample_bytree': 0.6087160373364486, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 73 with value: 26957452.814154092.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [95]	valid_0's l1: 1.57671
# [I 2024-12-02 14:51:54,432] Trial 78 finished with value: 29381155.183308613 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 50, 'max_depth': 8, 'max_bin': 391, 'min_data_in_leaf': 38, 'bagging_fraction': 0.7354653585039894, 'bagging_freq': 2, 'lambda_l1': 5, 'lambda_l2': 2, 'min_split_gain': 18, 'colsample_bytree': 0.7135336501167513, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 73 with value: 26957452.814154092.
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [768]	valid_0's l1: 1.37878
# [I 2024-12-02 14:51:55,148] Trial 79 finished with value: 27716624.903376162 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 59, 'max_depth': 8, 'max_bin': 421, 'min_data_in_leaf': 34, 'bagging_fraction': 0.8675093688017317, 'bagging_freq': 2, 'lambda_l1': 4, 'lambda_l2': 1, 'min_split_gain': 1, 'colsample_bytree': 0.6295668646583807, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 73 with value: 26957452.814154092.
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
#
and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 55, 'max_depth': 8, 'max_bin': 379, 'min_data_in_leaf': 33, 'bagging_fraction': 0.8642601516906795, 'bagging_freq': 2, 'lambda_l1': 5, 'lambda_l2': 2, 'min_split_gain': 0, 'colsample_bytree': 0.7044153504831803, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 73 with value: 26957452.814154092.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [107]	valid_0's l1: 1.52678
# [I 2024-12-02 14:52:01,950] Trial 90 finished with value: 28521467.835918553 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 48, 'max_depth': 8, 'max_bin': 382, 'min_data_in_leaf': 33, 'bagging_fraction': 0.8695923412643931, 'bagging_freq': 2, 'lambda_l1': 6, 'lambda_l2': 2, 'min_split_gain': 14, 'colsample_bytree': 0.7109977464864465, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 73 with value: 26957452.814154092.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [605]	valid_0's l1: 1.37035
# [I 2024-12-02 14:52:02,848] Trial 91 finished with value: 27636755.160351627 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 55, 'max_depth': 8, 'max_bin': 415, 'min_data_in_leaf': 38, 'bagging_fraction': 0.7727151563918104, 'bagging_freq': 2, 'lambda_l1': 5, 'lambda_l2': 1, 'min_split_gain': 0, 'colsample_bytree': 0.6306373515349087, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 73 with value: 26957452.814154092.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [699]	valid_0's l1: 1.38333
# [I 2024-12-02 14:52:03,502] Trial 92 finished with value: 26984946.672338877 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 60, 'max_depth': 8, 'max_bin': 377, 'min_data_in_leaf': 33, 'bagging_fraction': 0.8558173784267121, 'bagging_freq': 2, 'lambda_l1': 4, 'lambda_l2': 3, 'min_split_gain': 1, 'colsample_bytree': 0.6528112410942295, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 73 with value: 26957452.814154092.
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [854]	valid_0's l1: 1.37585
# [I 2024-12-02 14:52:04,235] Trial 93 finished with value: 27479515.370626587 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 60, 'max_depth': 8, 'max_bin': 384, 'min_data_in_leaf': 33, 'bagging_fraction': 0.8614919019114731, 'bagging_freq': 2, 'lambda_l1': 3, 'lambda_l2': 5, 'min_split_gain': 1, 'colsample_bytree': 0.7015716847195451, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 73 with value: 26957452.814154092.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [397]	valid_0's l1: 1.39292
# [I 2024-12-02 14:52:04,579] Trial 94 finished with value: 27323769.04226863 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 46, 'max_depth': 9, 'max_bin': 373, 'min_data_in_leaf': 46, 'bagging_fraction': 0.8071808852404859, 'bagging_freq': 2, 'lambda_l1': 3, 'lambda_l2': 3, 'min_split_gain': 2, 'colsample_bytree': 0.6476346870502125, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 73 with value: 26957452.814154092.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [503]	valid_0's l1: 1.38629
# [I 2024-12-02 14:52:05,025] Trial 95 finished with value: 27430246.113584224 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 58, 'max_depth': 8, 'max_bin': 398, 'min_data_in_leaf': 41, 'bagging_fraction': 0.9020570391479044, 'bagging_freq': 2, 'lambda_l1': 7, 'lambda_l2': 0, 'min_split_gain': 1, 'colsample_bytree': 0.7405373576698108, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 73 with value: 26957452.814154092.
# Training until validation scores don't improve for 100 rounds
# Did not meet early stopping. Best iteration is:
# [813]	valid_0's l1: 1.37744
# [I 2024-12-02 14:52:05,677] Trial 96 finished with value: 27758427.726831205 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 63, 'max_depth': 7, 'max_bin': 429, 'min_data_in_leaf': 37, 'bagging_fraction': 0.829575523684535, 'bagging_freq': 2, 'lambda_l1': 5, 'lambda_l2': 2, 'min_split_gain': 1, 'colsample_bytree': 0.5510231477913147, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 73 with value: 26957452.814154092.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [719]	valid_0's l1: 1.39166
# [I 2024-12-02 14:52:06,545] Trial 97 finished with value: 28799046.638976116 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 52, 'max_depth': 8, 'max_bin': 479, 'min_data_in_leaf': 118, 'bagging_fraction': 0.7925001318283604, 'bagging_freq': 2, 'lambda_l1': 4, 'lambda_l2': 3, 'min_split_gain': 0, 'colsample_bytree': 0.5960729654807803, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 73 with value: 26957452.814154092.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [371]	valid_0's l1: 1.39282
# [I 2024-12-02 14:52:06,976] Trial 98 finished with value: 26952985.50114311 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 49, 'max_depth': 9, 'max_bin': 419, 'min_data_in_leaf': 33, 'bagging_fraction': 0.8505937203819828, 'bagging_freq': 2, 'lambda_l1': 8, 'lambda_l2': 5, 'min_split_gain': 1, 'colsample_bytree': 0.7629215011942988, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 98 with value: 26952985.50114311.
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [308]	valid_0's l1: 1.40302
# [I 2024-12-02 14:52:07,287] Trial 99 finished with value: 27486550.26262302 and parameters: {'n_estimators': 857, 'learning_rate': 0.045309611206922125, 'num_leaves': 54, 'max_depth': 9, 'max_bin': 408, 'min_data_in_leaf': 44, 'bagging_fraction': 0.8518075518849305, 'bagging_freq': 2, 'lambda_l1': 6, 'lambda_l2': 5, 'min_split_gain': 2, 'colsample_bytree': 0.8412619048386681, 'objective': 'mae', 'verbosity': -1, 'random_state': 42}. Best is trial 98 with value: 26952985.50114311.

# %%
study_lgbm.best_params
# Out:
# {'n_estimators': 857,
#  'learning_rate': 0.045309611206922125,
#  'num_leaves': 49,
#  'max_depth': 9,
#  'max_bin': 419,
#  'min_data_in_leaf': 33,
#  'bagging_fraction': 0.8505937203819828,
#  'bagging_freq': 2,
#  'lambda_l1': 8,
#  'lambda_l2': 5,
#  'min_split_gain': 1,
#  'colsample_bytree': 0.7629215011942988,
#  'objective': 'mae',
#  'verbosity': -1,
#  'random_state': 42}

# %%
print(f'Best value = {study_lgbm.best_value}')
# Out:
# Best value = 26952985.50114311

# %%
# лучшие параметры модели до перезапуска ноутбука
lgbm_params = {
    'n_estimators': 857,
    'learning_rate': 0.045309611206922125,
    'num_leaves': 39,
    'max_depth': 9,
    'max_bin': 79,
    'min_data_in_leaf': 38,
    'bagging_fraction': 0.7830367186846483,
    'bagging_freq': 3,
    'lambda_l1': 3,
    'lambda_l2': 6,
    'min_split_gain': 2,
    'colsample_bytree': 0.6636806512095652,
    'objective': 'mae',
    'verbosity': -1,
    'random_state': 42
}

# %% [markdown]
# - сохраним лучшие параметры в файл

# %%
with open(config_train['params_path'], 'w') as f:
    json.dump(lgbm_params, f)

# %% [markdown]
# - обучим модель с лучшими параметрами и оценим ее метрики

# %%
# обучение модели на лучших параметрах для оценки метрик
eval_set = [(X_val, y_val)]

lgbm_optuna = LGBMRegressor(**lgbm_params)
lgbm_optuna.fit(X_train,
                y_train,
                eval_metric="mae",
                categorical_feature=config_train['category_cols'],
                eval_set=eval_set,
                callbacks=[early_stopping(stopping_rounds=100)])

y_pred = lgbm_optuna.predict(X_test)
# Out:
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [246]	valid_0's l1: 1.40474

# %% [markdown]
# ## Метрики

# %%
def r2_adjusted(y_true: np.ndarray, y_pred: np.ndarray,
                X_test: np.ndarray) -> float:
    '''
    Вычисление коэффициента детерминации для множественной регрессии
    
    Parameters
    -----------
    y_test: np.ndarray
        тестовые значения y
    y_pred: np.ndarray
        предсказания модели
    X_test: np.ndarray
        тестовые значения X
    
    Returns
    ----------
    Значение метрики
    '''
    n_objects = len(y_true)
    n_features = X_test.shape[1]
    r2 = r2_score(y_true, y_pred)
    return 1 - (1 - r2) * (n_objects - 1) / (n_objects - n_features - 1)


def wape(y_true: np.ndarray, y_pred: np.ndarray) -> float:
    '''
    Вычисление взвешенной абсолютной процентной ошибки
    
    Parameters
    -----------
    y_test: np.ndarray
        тестовые значения y
    y_pred: np.ndarray
        предсказания модели
    
    Returns
    ----------
    Значение метрики
    '''
    return np.sum(np.abs(y_pred - y_true)) * 100 / np.sum(y_true)


def rmsle(y_true: np.ndarray, y_pred: np.ndarray) -> np.float64:
    '''
    Вычисление среднеквадратической логарифмической ошибки
    
    Parameters
    -----------
    y_test: np.ndarray
        тестовые значения y
    y_pred: np.ndarray
        предсказания модели 
        
    Returns
    ----------
    Значение метрики
    '''
    try:
        return np.sqrt(mean_squared_log_error(y_true, y_pred))
    except:
        return None


def get_metrics(y_test: np.ndarray, y_pred: np.ndarray, X_test: np.ndarray,
                name: str) -> pd.DataFrame:
    '''
    Создание таблицы с основными метриками для модели
    
    Parameters
    ----------
    y_test: np.ndarray
        тестовые значения y
    y_pred: np.ndarray
        предсказания модели
    X_test: np.ndarray
        тестовые значения X
    Returns
    ----------
    датафрейм с метриками
    '''
    metrics = pd.DataFrame()

    metrics['model'] = [name]
    metrics['MSE'] = mean_squared_error(y_test, y_pred)
    metrics['RMSE'] = np.sqrt(mean_squared_error(y_test, y_pred))
    metrics['RMSLE'] = rmsle(y_test, y_pred)
    metrics['MAE'] = mean_absolute_error(y_test, y_pred)
    metrics['R2 adjusted'] = r2_adjusted(y_test, y_pred, X_test)
    metrics['WAPE_%'] = wape(y_test, y_pred)

    return metrics

# %%
def check_overfitting(model: LGBMRegressor, X_train: np.ndarray,
                      y_train: np.ndarray, X_test: np.ndarray,
                      y_test: np.ndarray, metric: Callable,
                      model_name: str) -> None:
    '''
    Проверяет переобучилась ли модель
    
    Parameters
    ----------
    model: LGBMRegressor
        модель
    X_train: np.ndarray
        тренировочные данные
    y_train: np.ndarray
        тренировочные значения y
    X_test: np.ndarray
        тестовые данные
    y_test: np.ndarray
        тестовые значения y
    metric: Callable
        функция-метрика для оценки переобучения
    model_name: str
        название модели
    
    Returns
    ----------
    Данные о переобучении и метрики на train и test
    '''
    y_pred_train = model.predict(X_train)
    y_pred_test = model.predict(X_test)

    metric_train = metric(np.exp(y_train), np.exp(y_pred_train))
    metric_test = metric(np.exp(y_test), np.exp(y_pred_test))

    print(f'Рассчет переобучения {model_name}')
    print(f'{metric.__name__} на train: {round(metric_train, 2)}')
    print(f'{metric.__name__} на test: {round(metric_test, 2)}')
    print(
        f'delta = {round((abs(metric_train - metric_test) / metric_test*100), 1)}%'
    )

# %%
# импорт метрик с baseline
metrics = pd.read_json(config_train['metrics_path'])

# %%
metrics
# Out:
#                                     MSE          RMSE     RMSLE           MAE  \
# CatBoostBaselineTrain  5894928942723778  7.677844e+07  1.799804  2.420852e+07
# CatBoostBaselineTest   5843035434928676  7.643975e+07  1.944247  2.780998e+07
# LGBMBaselineTrain      6377899338583602  7.986175e+07  1.760601  2.259239e+07
# LGBMBaselineTest       5542783863964557  7.444987e+07  1.973105  2.715035e+07
#
#                        R2 adjusted     WAPE_%
# CatBoostBaselineTrain     0.715322  48.974804
# CatBoostBaselineTest      0.658584  55.508199
# LGBMBaselineTrain         0.691999  45.705303
# LGBMBaselineTest          0.676128  54.191586

# %%
metrics = pd.concat([
    metrics,
    get_metrics(np.exp(y_train), np.exp(lgbm_optuna.predict(X_train)), X_train,
                'LGBMTunedTrain').set_index('model'),
    get_metrics(np.exp(y_test), np.exp(y_pred), X_test, 'LGBMTunedTest').set_index('model')
])

# %%
metrics
# Out:
#                                 MSE          RMSE     RMSLE           MAE  \
# CatBoostBaselineTrain  5.894929e+15  7.677844e+07  1.799804  2.420852e+07
# CatBoostBaselineTest   5.843035e+15  7.643975e+07  1.944247  2.780998e+07
# LGBMBaselineTrain      6.377899e+15  7.986175e+07  1.760601  2.259239e+07
# LGBMBaselineTest       5.542784e+15  7.444987e+07  1.973105  2.715035e+07
# LGBMTunedTrain         7.189569e+15  8.479133e+07  1.797810  2.542100e+07
# LGBMTunedTest          5.274787e+15  7.262773e+07  1.953873  2.671265e+07
#
#                        R2 adjusted     WAPE_%
# CatBoostBaselineTrain     0.715322  48.974804
# CatBoostBaselineTest      0.658584  55.508199
# LGBMBaselineTrain         0.691999  45.705303
# LGBMBaselineTest          0.676128  54.191586
# LGBMTunedTrain            0.652802  51.427701
# LGBMTunedTest             0.691788  53.317938

# %% [markdown]
# - в результате подбора параметров значение MAE на тренировочных данных немного ухудшилось, а на тестовых улучшилось
# - такая же ситуация и с другими метриками

# %%
# проверка на переобучение
check_overfitting(lgbm_optuna, X_train, y_train, X_test, y_test,
                  mean_absolute_error, 'LightGBMTuned')
# Out:
# Рассчет переобучения LightGBMTuned
# mean_absolute_error на train: 25421004.84
# mean_absolute_error на test: 26712648.19
# delta = 4.8%

# %% [markdown]
# - у baseline модели переобучение равнялось 16.8 процентам, то есть оно **уменьшилось почти в 4 раза**

# %% [markdown]
# # Кросс валидация

# %% [markdown]
# - оценим метрики модели с кросс валидацией

# %%
def cross_validation(X_train: pd.DataFrame, y_train: pd.Series,
                     X_test: pd.DataFrame, y_test: pd.Series, params: dict,
                     num_folds: int, random_state: int, cat_features):
    '''
    Функция для кросс валидации модели (метрика - MAE)
    
    Parameters
    ------------
    X_train: np.ndarray
        тренировочные данные
    y_train: np.ndarray
        тренировочные значения y
    X_test: np.ndarray
        тестовые данные
    y_test: np.ndarray
        тестовые значения y
    params: dict
        словарь с параметрами модели
    num_folds: int
        количество фолдов
    random_state: int
        значение random state
                     
    Returns
    ------------
        значения метрики на out-of-fold и предстказания модели на тесте
    '''

    folds = KFold(n_splits=num_folds, random_state=random_state, shuffle=True)
    score_oof = []
    predictions_test = []

    for fold, (train_index,
               test_index) in enumerate(folds.split(X_train, y_train)):
        X_train_, X_val = X_train.iloc[train_index], X_train.iloc[test_index]
        y_train_, y_val = y_train.iloc[train_index], y_train.iloc[test_index]
        y_val_exp = np.exp(y_val)

        model = LGBMRegressor(**params)
        model.fit(X_train_,
                  y_train_,
                  eval_set=[(X_val, y_val)],
                  eval_metric="mae",
                  categorical_feature=cat_features)

        y_pred_val = np.exp(model.predict(X_val))
        y_pred = np.exp(model.predict(X_test))
        mae_oof = mean_absolute_error(y_val_exp, y_pred_val)

        print(f'{fold + 1} MAE score = {round(mae_oof, 3)}')
        print('-----')

        score_oof.append(mae_oof)
        predictions_test.append(y_pred)

    return score_oof, predictions_test

# %%
# получение предсказаний с помощтю кросс валидации
score_oof, predictions_test = cross_validation(X_train,
                                               y_train,
                                               X_test,
                                               y_test,
                                               params=lgbm_params,
                                               num_folds=N_FOLDS,
                                               random_state=RAND,
                                               cat_features=config_train['category_cols'])
# Out:
# 1 MAE score = 28550074.608
# -----
# 2 MAE score = 31085332.122
# -----
# 3 MAE score = 29423273.784
# -----
# 4 MAE score = 28609319.346
# -----
# 5 MAE score = 27955986.939
# -----

# %%
pred_test_cv = np.mean(predictions_test, axis=0)

print(f'Среднее значение MAE на out-of-fold: {round(np.mean(score_oof), 3)}')
print(f'std MAE на out-of-fold: {round(np.std(score_oof), 3)}')
print(
    f'Значение MAE на тестовых данных: {round(mean_absolute_error(np.exp(y_test), pred_test_cv), 3)}'
)
# Out:
# Среднее значение MAE на out-of-fold: 29124797.36
# std MAE на out-of-fold: 1085810.882
# Значение MAE на тестовых данных: 27285603.136

# %%
metrics = pd.concat(
    [metrics,
     get_metrics(np.exp(y_test), pred_test_cv, X_test, 'LGBMCVTest').set_index('model')])

# %%
metrics.style.highlight_min(
    axis=0, color='lightblue').highlight_max(axis=0, color='lightpink')
# Out:
# <style type="text/css">
# #T_7804a_row0_col4, #T_7804a_row1_col3, #T_7804a_row1_col5, #T_7804a_row3_col2, #T_7804a_row4_col0, #T_7804a_row4_col1 {
#   background-color: lightpink;
# }
# #T_7804a_row2_col2, #T_7804a_row2_col3, #T_7804a_row2_col5, #T_7804a_row4_col4, #T_7804a_row5_col0, #T_7804a_row5_col1 {
#   background-color: lightblue;
# }
# </style>
# <table id="T_7804a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7804a_level0_col0" class="col_heading level0 col0" >MSE</th>
#       <th id="T_7804a_level0_col1" class="col_heading level0 col1" >RMSE</th>
#       <th id="T_7804a_level0_col2" class="col_heading level0 col2" >RMSLE</th>
#       <th id="T_7804a_level0_col3" class="col_heading level0 col3" >MAE</th>
#       <th id="T_7804a_level0_col4" class="col_heading level0 col4" >R2 adjusted</th>
#       <th id="T_7804a_level0_col5" class="col_heading level0 col5" >WAPE_%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7804a_level0_row0" class="row_heading level0 row0" >CatBoostBaselineTrain</th>
#       <td id="T_7804a_row0_col0" class="data row0 col0" >5894928942723778.000000</td>
#       <td id="T_7804a_row0_col1" class="data row0 col1" >76778440.611436</td>
#       <td id="T_7804a_row0_col2" class="data row0 col2" >1.799804</td>
#       <td id="T_7804a_row0_col3" class="data row0 col3" >24208523.565597</td>
#       <td id="T_7804a_row0_col4" class="data row0 col4" >0.715322</td>
#       <td id="T_7804a_row0_col5" class="data row0 col5" >48.974804</td>
#     </tr>
#     <tr>
#       <th id="T_7804a_level0_row1" class="row_heading level0 row1" >CatBoostBaselineTest</th>
#       <td id="T_7804a_row1_col0" class="data row1 col0" >5843035434928676.000000</td>
#       <td id="T_7804a_row1_col1" class="data row1 col1" >76439750.358885</td>
#       <td id="T_7804a_row1_col2" class="data row1 col2" >1.944247</td>
#       <td id="T_7804a_row1_col3" class="data row1 col3" >27809983.773220</td>
#       <td id="T_7804a_row1_col4" class="data row1 col4" >0.658584</td>
#       <td id="T_7804a_row1_col5" class="data row1 col5" >55.508199</td>
#     </tr>
#     <tr>
#       <th id="T_7804a_level0_row2" class="row_heading level0 row2" >LGBMBaselineTrain</th>
#       <td id="T_7804a_row2_col0" class="data row2 col0" >6377899338583602.000000</td>
#       <td id="T_7804a_row2_col1" class="data row2 col1" >79861751.411947</td>
#       <td id="T_7804a_row2_col2" class="data row2 col2" >1.760601</td>
#       <td id="T_7804a_row2_col3" class="data row2 col3" >22592390.786591</td>
#       <td id="T_7804a_row2_col4" class="data row2 col4" >0.691999</td>
#       <td id="T_7804a_row2_col5" class="data row2 col5" >45.705303</td>
#     </tr>
#     <tr>
#       <th id="T_7804a_level0_row3" class="row_heading level0 row3" >LGBMBaselineTest</th>
#       <td id="T_7804a_row3_col0" class="data row3 col0" >5542783863964557.000000</td>
#       <td id="T_7804a_row3_col1" class="data row3 col1" >74449874.841833</td>
#       <td id="T_7804a_row3_col2" class="data row3 col2" >1.973105</td>
#       <td id="T_7804a_row3_col3" class="data row3 col3" >27150351.399408</td>
#       <td id="T_7804a_row3_col4" class="data row3 col4" >0.676128</td>
#       <td id="T_7804a_row3_col5" class="data row3 col5" >54.191586</td>
#     </tr>
#     <tr>
#       <th id="T_7804a_level0_row4" class="row_heading level0 row4" >LGBMTunedTrain</th>
#       <td id="T_7804a_row4_col0" class="data row4 col0" >7189569218544470.000000</td>
#       <td id="T_7804a_row4_col1" class="data row4 col1" >84791327.496062</td>
#       <td id="T_7804a_row4_col2" class="data row4 col2" >1.797810</td>
#       <td id="T_7804a_row4_col3" class="data row4 col3" >25421004.843735</td>
#       <td id="T_7804a_row4_col4" class="data row4 col4" >0.652802</td>
#       <td id="T_7804a_row4_col5" class="data row4 col5" >51.427701</td>
#     </tr>
#     <tr>
#       <th id="T_7804a_level0_row5" class="row_heading level0 row5" >LGBMTunedTest</th>
#       <td id="T_7804a_row5_col0" class="data row5 col0" >5274786586876454.000000</td>
#       <td id="T_7804a_row5_col1" class="data row5 col1" >72627726.020277</td>
#       <td id="T_7804a_row5_col2" class="data row5 col2" >1.953873</td>
#       <td id="T_7804a_row5_col3" class="data row5 col3" >26712648.187854</td>
#       <td id="T_7804a_row5_col4" class="data row5 col4" >0.691788</td>
#       <td id="T_7804a_row5_col5" class="data row5 col5" >53.317938</td>
#     </tr>
#     <tr>
#       <th id="T_7804a_level0_row6" class="row_heading level0 row6" >LGBMCVTest</th>
#       <td id="T_7804a_row6_col0" class="data row6 col0" >5439166473047449.000000</td>
#       <td id="T_7804a_row6_col1" class="data row6 col1" >73750704.898648</td>
#       <td id="T_7804a_row6_col2" class="data row6 col2" >1.969568</td>
#       <td id="T_7804a_row6_col3" class="data row6 col3" >27285603.135889</td>
#       <td id="T_7804a_row6_col4" class="data row6 col4" >0.682183</td>
#       <td id="T_7804a_row6_col5" class="data row6 col5" >54.461545</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# - MAE на кросс валидации немного хуже, чем без нее, но эта разница совсем небольшая
# - остальные же метрики с кросс валидацией улучшились
# - то есть можно прийти к выводу, что модель работает довольно стабильно

# %% [markdown]
# - сохраним лучшую модель в файл

# %%
joblib.dump(lgbm_optuna, config_train['model_path'])
# Out:
# ['../models/best_model.joblib']

# %% [markdown]
# - сохраним полученный датасет с метриками в тот же файл

# %%
metrics.to_json(config_train['metrics_path'])
